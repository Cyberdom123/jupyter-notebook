# %%
import numpy as np

x = np.random.choice([-1,1])
print(x)
# Out:
# -1

# %%
import numpy as np
def T(n):
    if n == 1:
        return 1
    else:
        return np.random.choice([-1,1]) + T(n-1)
    
[T(i) for i in range(1,10)]
# Out:
# [1, 2, 1, 0, 1, 0, 1, -2, -5]

# %%
# Out:
# 2*exp(2*x)
# exp(2*x)
